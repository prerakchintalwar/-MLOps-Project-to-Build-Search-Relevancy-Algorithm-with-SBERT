# %%
import os

current_dir = os.getcwd()

# Get the parent directory path
parent_dir = os.path.dirname(current_dir)

# Change the current working directory to the parent directory which should be the root folder
os.chdir(parent_dir)

# Verify the new working directory
new_dir = os.getcwd()
print("Current working directory:", new_dir)
# Out:
# Current working directory: d:\PROJECTS\REVIEWED PROJECTS\camille_projects-p03_semantic-search\semantic-search

# %%
try:
    from src import config
    from src import utils
    from src import preprocessor
    from src import build_index
    from src import embeddings
    from src import search
except:
    import config
    import utils
    import preprocessor
    import build_index
    import embeddings

import pandas as pd
import os
from pprint import pprint
import logging
from functools import reduce


logger = utils.logger

# %%
# 1. Collect and preprocess data: The preprocessed data will be dumped into a new file
logger.info("Collecting and preprocessing data ...")
output_filename = utils.get_raw_data_from_aws_mongo()
r = preprocessor.preprocess_data(output_filename, section_by=config.TEXT_SECTION_TYPE, input_types=config.TRAIN_DATA_INPUT_TYPES, sample_size=config.SAMPLE_SIZE)

# %%
# 2. Compute embeddings: This will dump the embeddings into a new file
pdf = pd.read_csv(r["path_to_processed_text"])

data = dict(
            zip(
                pdf["section_id"].values.tolist(), 
                embeddings.get_embeddings_from_lemmatized_sentences(pdf["text"].values.tolist())
            )
        )
utils.save_json(data, os.path.join(config.DATA_DIR, "processed", f"{config.TEXT_SECTION_TYPE}_" + "_".join(config.TRAIN_DATA_INPUT_TYPES) + "_embeddings.json"))

# %%
# 3. Load embeddings and build annoy index

_embeddings = utils.load_json(os.path.join(config.DATA_DIR, "processed", f"{config.TEXT_SECTION_TYPE}_" + "_".join(config.TRAIN_DATA_INPUT_TYPES) + "_embeddings.json"))
index = build_index.init_index(index_type=config.SEARCH_INDEX_TYPE)
index.build(_embeddings, os.path.join(config.MODELS_DIR, config.SEARCH_INDEX))

# %%
index.load(os.path.join(config.MODELS_DIR, config.SEARCH_INDEX))
ids_mapper = utils.load_json(os.path.join(config.MODELS_DIR, f"{config.TEXT_SECTION_TYPE}_" + "_".join(config.TRAIN_DATA_INPUT_TYPES) + "_ids.json"))
query_emb = [_embeddings["0"], _embeddings["1"], _embeddings["20"]]
results = index.search(query_emb, 5, ids_lookup=ids_mapper["section_id_to_article_id"])
print(results)
# Out:
# [[(0, 0.0), (618, 0.9278080463409424), (13039, 0.9894830584526062), (2865, 0.9895022511482239), (154, 0.9913226366043091)], [(1, 0.0), (3101, 0.9495759010314941), (228, 0.9650539755821228), (13057, 0.9904249310493469), (993, 0.990619421005249)], [(20, 0.0), (9652, 1.0283305644989014), (13144, 1.099655270576477), (13189, 1.1079797744750977), (5983, 1.1306354999542236)]]

# %%
ids_mapper = utils.load_json(os.path.join(config.MODELS_DIR, f"{config.TEXT_SECTION_TYPE}_" + "_".join(config.TRAIN_DATA_INPUT_TYPES) + "_ids.json"))
sections_stats = utils.load_json(os.path.join(config.MODELS_DIR, f"{config.TEXT_SECTION_TYPE}_{'_'.join(config.TRAIN_DATA_INPUT_TYPES)}_stats.json"))["sections_by_article"]

# queries = [lookup[i]["title"] for i in (0, 1)]
queries = [
    "Carbon emission",
    "debt reduction among companies",
    "lack of medical devices in hospitals",
    "covid-19 vaccine development",
    "women entrepreneuship in india",
]

print(queries)
results = search.search(index, queries, 5, ids_mapper, sections_stats)
pprint(results)
# Out:
# ['Carbon emission', 'debt reduction among companies', 'lack of medical devices in hospitals', 'covid-19 vaccine development', 'women entrepreneuship in india']
# [{'query': 'Carbon emission', 'results': []},
#  {'query': 'debt reduction among companies',
#   'results': [{'article_id': 1386,
#                'category': 'business, finance & economics',
#                'score': 0.53,
#                'subcategory': 'equity - private & public',
#                'title': 'We Think Balco Group (STO:BALCO) Can Stay On Top Of '
#                         'Its Debt'},
#               {'article_id': 13029,
#                'category': 'us media',
#                'score': 0.48,
#                'subcategory': 'us - entrepreneur & startup',
#                'title': 'Egyptian B2B trucking startup Trella secures further '
#                         '$6m debt funding'},
#               {'article_id': 1389,
#                'category': 'business, finance & economics',
#                'score': 0.46,
#                'subcategory': 'equity - private & public',
#                'title': 'Analysis: European dealmakers face shrinking debt '
#                         'options as recession risk looms'},
#               {'article_id': 4513,
#                'category': 'general news & current affairs',
#                'score': 0.46,
#                'subcategory': 'foreign affairs/world',
#                'title': 'Zambia on track for debt restructuring next quarter '
#                         '-finance minister'},
#               {'article_id': 5028,
#                'category': 'general news & current affairs',
#                'score': 0.46,
#                'subcategory': 'investigative reporting',
#                'title': 'Debt-ridden Thurrock Council owes other Essex '
#                         'authorities millions'}]},
#  {'query': 'lack of medical devices in hospitals',
#   'results': [{'article_id': 333,
#                'category': 'asia media',
#                'score': 0.61,
#                'subcategory': 'asia - health, medicine, pharmacy industry',
#                'title': 'Why India is lacking in medical device manufacturing '
#                         'despite being one of fastest growing healthcare '
#                         'markets?'},
#               {'article_id': 6116,
#                'category': 'health & medicine',
#                'score': 0.52,
#                'subcategory': 'medicine & health - vision & hearing impaired',
#                'title': 'Technologies that will shape the future of '
#                         'healthcare'},
#               {'article_id': 5467,
#                'category': 'health & medicine',
#                'score': 0.5,
#                'subcategory': 'medicine & health',
#                'title': 'Medical Devices industry M&A deals total $320.6m '
#                         'globally in March 2022'},
#               {'article_id': 5601,
#                'category': 'health & medicine',
#                'score': 0.48,
#                'subcategory': 'medicine & health - asthma',
#                'title': 'Tele-Health Innovation: AI and IoT as enablers for '
#                         'patient safety and clinician efficiency'},
#               {'article_id': 5635,
#                'category': 'health & medicine',
#                'score': 0.48,
#                'subcategory': 'medicine & health - asthma',
#                'title': 'Digital therapeutics: Digital revolution in '
#                         'healthcare'}]},
#  {'query': 'covid-19 vaccine development',
#   'results': [{'article_id': 4509,
#                'category': 'general news & current affairs',
#                'score': 0.85,
#                'subcategory': 'general news - sa only',
#                'title': 'Overview of COVID-19 Vaccines'},
#               {'article_id': 5840,
#                'category': 'health & medicine',
#                'score': 0.81,
#                'subcategory': 'medicine & health - disability',
#                'title': 'Pediatric COVID-19 Vaccine'},
#               {'article_id': 5550,
#                'category': 'health & medicine',
#                'score': 0.78,
#                'subcategory': 'medicine & health - arthritis',
#                'title': 'Clinical Guidance for COVID-19 Vaccination'},
#               {'article_id': 5740,
#                'category': 'health & medicine',
#                'score': 0.77,
#                'subcategory': 'medicine & health - disability',
#                'title': 'COVID-19 Vaccine Booster Shots'},
#               {'article_id': 990,
#                'category': 'business, finance & economics',
#                'score': 0.74,
#                'subcategory': 'business appointments',
#                'title': 'COVID-19: Vaccines for 6 Months to Under 5 Years '
#                         'Old'}]},
#  {'query': 'women entrepreneuship in india',
#   'results': [{'article_id': 939,
#                'category': 'business, finance & economics',
#                'score': 0.54,
#                'subcategory': 'business - female specific',
#                'title': 'Govt data: Only 18% of 1 crore registered MSMEs owned '
#                         'by women entrepreneurs'},
#               {'article_id': 776,
#                'category': 'business, finance & economics',
#                'score': 0.53,
#                'subcategory': 'business - female specific',
#                'title': 'Does gender-based discrimination harm women’s health '
#                         'in India?'},
#               {'article_id': 6794,
#                'category': 'lifestyle',
#                'score': 0.51,
#                'subcategory': "fashion - women's",
#                'title': 'Neeti Mehta Shukla Honored with Technology Pioneer '
#                         "Award by Women's Entrepreneurship Day Organization "
#                         '(WEDO)'},
#               {'article_id': 7383,
#                'category': 'lifestyle',
#                'score': 0.48,
#                'subcategory': 'regional tourism',
#                'title': 'Chalo India: Sab Pravasi Ka Prayas – Calling Indian '
#                         'expatriates to become tourism’s Rashtradoots'},
#               {'article_id': 8017,
#                'category': 'multicultural press',
#                'score': 0.48,
#                'subcategory': 'multicultural press - pacific islander',
#                'title': 'Why India needs to elaborate on its policy towards '
#                         'the ‘Indo-Caribbean’ diaspora'}]}]

# %%
'''
{
    "query" :[
    "Carbon emission",
    "debt reduction among companies",
    "lack of medical devices in hospitals",
    "covid-19 vaccine development",
    "women entrepreneuship in india"
],
    "k" : 3
}
'''
